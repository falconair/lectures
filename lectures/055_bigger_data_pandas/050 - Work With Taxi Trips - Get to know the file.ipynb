# %%
import pandas as pd

# %%
data_df = pd.read_feather("../../datasets/taxi-trips/taxi_trips_small.feather")

# %%
data_df.head(3).T

# %%
data_df.info()

# %%
data_df.columns

# %%
len(data_df.columns)

# %%
dict(data_df.dtypes)
