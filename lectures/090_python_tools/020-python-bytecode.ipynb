# %%
import dis

# %%
def loop_f(x):
    for i in range(x):
        print(i)

# %%
def listcomp_f(x):
    [print(i) for i in range(x)]

# %%
loop_f(3)

# %%
listcomp_f(3)

# %%
dis.dis(loop_f)

# %%
dis.dis(listcomp_f)
